# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
targets = df.species
inputs = df.drop('species', axis=1)
model = DecisionTreeClassifier(ccp_alpha=0.01)
model.fit(inputs, targets)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01)

# %%
fig = plt.figure(figsize=(15,10))
plot_tree(model, feature_names=inputs.columns, class_names=targets.unique(), filled=True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
preds = model.predict(inputs)
confusion_matrix(preds, targets)
# Out:
# array([[50,  0,  0],
#        [ 0, 49,  5],
#        [ 0,  1, 45]], dtype=int64)

# %%
dummy = pd.get_dummies(df, 'species')
## pd.concat([df,dummy], axis=1).drop(columns="species")
dummy
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_setosa  \
# 0             5.1          3.5           1.4          0.2               1
# 1             4.9          3.0           1.4          0.2               1
# 2             4.7          3.2           1.3          0.2               1
# 3             4.6          3.1           1.5          0.2               1
# 4             5.0          3.6           1.4          0.2               1
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3               0
# 146           6.3          2.5           5.0          1.9               0
# 147           6.5          3.0           5.2          2.0               0
# 148           6.2          3.4           5.4          2.3               0
# 149           5.9          3.0           5.1          1.8               0
#
#      species_versicolor  species_virginica
# ...
